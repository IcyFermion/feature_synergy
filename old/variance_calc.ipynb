# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
res_df = pd.read_csv('./arabidopsis_network_v_model.csv', index_col=0)

# %%
df = pd.read_csv('../data/GSE97500/test_target_tpm.csv', index_col=0)
df

# %%
res_df['test_var'] = df.loc[res_df.index].var(axis=1)
res_df['test_std'] = df.loc[res_df.index].std(axis=1)

# %%
res_df.to_csv('./arabidopsis_network_v_model.csv')

# %%
res_df
# Out:
#            rf_score  linear_score  gs_rf_score  gs_linear_score  \
# AT3G27000 -0.767518     -1.532036    -0.833818        -0.831322
# AT5G64710  0.124998     -0.195373     0.135024        -0.187645
# AT5G39160  0.403961      0.159759     0.415337         0.233096
# AT4G14720 -0.883586     -1.309160    -0.857421        -0.844400
# AT3G16760  0.264630      0.214389     0.395370         0.104510
# ...             ...           ...          ...              ...
# AT5G51470  0.056159     -0.230555    -0.086823        -0.291544
# AT5G46910 -0.408319     -1.382779    -0.407004        -1.633407
# AT3G52470 -0.057128     -0.346429    -0.122206        -0.263469
# AT3G60860  0.358709      0.389265     0.260318         0.418564
# AT2G25310  0.534461      0.611297     0.426349        -0.041572
#
#            rf_with_linear_top_features_score  \
# AT3G27000                          -0.529806
# AT5G64710                           0.303669
# AT5G39160                           0.435733
# ...

# %%
df = pd.read_csv('../data/bsubtilis/GSE224332/GSM7689341_LagPhase_Rep1_0min_normalizedCounts2.csv.gz', compression='gzip')['edgeR-normalized count (log2)']

# %%
df.min()
# Out:
# -1.56102954154762
