# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
perturbation_factor = 3

# %%
from itertools import chain, combinations

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
ts_df = pd.read_csv('data/TS/expression.tsv', sep='\t', index_col=0)
ts_df
# Out:
#              SS_N_0    SS_N_1    SS_N_2    SS_N_3    SS_N_4    SS_N_5  \
# AT2G23320  8.719703  8.854234  8.339660  8.325063  7.991407  8.819359
# AT2G23290  6.539835  6.331182  6.589742  6.169512  6.230631  6.504109
# AT2G47460  6.592404  6.663808  6.665230  7.380857  7.591244  6.810912
# AT2G47520  6.186486  5.707548  5.553482  7.907751  4.954221  4.269210
# AT4G25560  4.947942  5.039360  5.068459  5.298248  6.626528  6.922663
# ...             ...       ...       ...       ...       ...       ...
# AT2G26650  9.279982  9.471561  9.385928  8.712459  9.205193  9.446869
# AT2G26690  5.334807  5.604232  5.420387  6.349184  6.096268  5.370981
# AT2G26670  9.426066  9.203066  8.575636  8.419305  8.996381  9.171989
# AT2G42250  6.084767  5.473268  4.903548  5.002190  7.934024  6.591885
# AT2G42220  5.285906  4.961226  5.184456  5.080645  4.705689  4.537632
#
#              SS_N_6    SS_N_7    SS_N_8    SS_N_9  ...   TS_C_2_0   TS_C_3_0  \
# AT2G23320  8.343122  8.100111  8.048919  8.565047  ...   8.716126   8.715351
# AT2G23290  5.984810  6.336953  6.484445  6.351427  ...   7.082071   7.142681
# AT2G47460  7.510426  6.734630  8.350421  6.426653  ...   9.814811   9.160006
# AT2G47520  4.666858  4.908275  4.826998  4.899628  ...   7.485941   7.301451
# AT4G25560  6.781308  6.713108  6.639420  6.822980  ...   6.128787   6.040401
# ...             ...       ...       ...       ...  ...        ...        ...
# AT2G26650  9.406291  9.268829  8.896274  8.809928  ...   8.763297   8.357066
# AT2G26690  5.822037  5.238184  5.694367  5.397120  ...   4.850134   5.487063
# AT2G26670  9.325521  9.105899  9.124833  9.340901  ...  10.105470  10.143546
# AT2G42250  8.359848  6.192340  8.272375  6.678681  ...   9.038308   8.599493
# AT2G42220  4.559494  4.602869  5.011033  5.349990  ...   4.591214   4.410271
#
#             TS_C_4_0   TS_C_5_0  TS_C_0_1  TS_C_1_1   TS_C_2_1   TS_C_3_1  \
# AT2G23320   8.707970   8.593127  9.179653  8.716875   8.688589   8.631035
# AT2G23290   7.258557   7.397112  6.940961  7.273025   6.795654   7.340082
# AT2G47460   9.138006   7.961055  8.823516  8.247743  10.194548   9.165110
# AT2G47520   7.845690   5.497004  7.336866  5.690559   7.911646   8.129610
# AT4G25560   5.977783   5.616901  6.440168  6.399311   6.340829   6.134249
# ...              ...        ...       ...       ...        ...        ...
# AT2G26650   8.959311   8.428475  7.063986  7.068268   8.730050   8.404524
# AT2G26690   4.806368   5.329299  5.288093  5.164750   4.768301   5.190918
# AT2G26670  10.110567  10.160674  9.866627  8.669913  10.443128  10.175350
# AT2G42250   8.824057   7.795542  7.964822  8.650761   8.285258   9.041712
# AT2G42220   4.553326   4.543298  5.203287  5.279488   4.591950   4.492438
#
#             TS_C_4_1   TS_C_5_1
# AT2G23320   8.818906   8.510758
# AT2G23290   7.375668   7.202944
# AT2G47460   9.560325   8.143590
# AT2G47520   8.725803   5.142120
# AT4G25560   6.274303   5.967895
# ...              ...        ...
# AT2G26650   8.626117   8.508589
# AT2G26690   5.235409   5.547688
# AT2G26670  10.186553  10.127917
# AT2G42250   8.331855   8.291843
# AT2G42220   4.639774   4.354981
#
# [2286 rows x 131 columns]

# %%
ss_df = pd.read_csv('data/SS/col4_counts.csv', index_col=0)
ss_df
# Out:
#                  wt-40_HPK-1S  col4-0.5_HPLK-3R  wt-40_LPK-1R  col4-40_LPK-3S  \
# Gene
# AT1G01010                   3                 9            21               1
# AT1G01020                  28                26            40              27
# AT1G03987                   0                 0             0               0
# AT1G01030                  36                 3             9              10
# AT1G01040                  61                42            76              36
# ...                       ...               ...           ...             ...
# ATCG01280                   0                 0             0               0
# ATCG01290                   0                 0             0               0
# ATCG01300                   0                 0             0               0
# ATCG01310                   0                 0             0               0
# ENSRNA049494914             0                 0             0               0
#
#                  wt-10_LPK-2S  col4-0.5_LPK-1S  wt-0.5_LPHK-1S  wt-40_HPK-3R  \
# Gene
# AT1G01010                   1                1               0             2
# AT1G01020                   3               30               5            19
# AT1G03987                   0                0               0             0
# AT1G01030                   1               30               5             3
# AT1G01040                   0               34              10            26
# ...                       ...              ...             ...           ...
# ATCG01280                   0                0               0             0
# ATCG01290                   0                0               0             0
# ATCG01300                   0                0               0             0
# ATCG01310                   0                0               0             0
# ENSRNA049494914             0                0               0             0
#
#                  col4-0.5_HPLK-3S  col4-0.5_LPK-2R  ...  col4-0.5_LPK-2S  \
# Gene                                                ...
# AT1G01010                       4               29  ...                2
# AT1G01020                      24               52  ...               25
# AT1G03987                       0                0  ...                0
# AT1G01030                      38                6  ...               22
# AT1G01040                      25               50  ...               30
# ...                           ...              ...  ...              ...
# ATCG01280                       0                0  ...                0
# ATCG01290                       0                0  ...                0
# ATCG01300                       0                0  ...                0
# ATCG01310                       0                0  ...                0
# ENSRNA049494914                 0                0  ...                0
#
#                  wt-10_LPK-5S  wt-0.5_HPLK-2S  wt-0.5_HPLK-3S  col4-40_HPK-3R  \
# Gene
# AT1G01010                   0               1               2              40
# AT1G01020                   0              46              32              78
# AT1G03987                   0               0               0               0
# AT1G01030                   2              50              31               7
# AT1G01040                   0              59              62              80
# ...                       ...             ...             ...             ...
# ATCG01280                   0               0               0               0
# ATCG01290                   0               0               0               0
# ATCG01300                   0               0               0               0
# ATCG01310                   0               0               0               0
# ENSRNA049494914             0               0               0               0
#
#                  col4-0.5_HPK-2R  wt-0.5_LPHK-2R  wt-40_LPHK-3R  \
# Gene
# AT1G01010                     18              14              8
# AT1G01020                     33              23             16
# AT1G03987                      0               0              0
# AT1G01030                      3              12              6
# AT1G01040                     25              79             48
# ...                          ...             ...            ...
# ATCG01280                      0               0              0
# ATCG01290                      0               0              0
# ATCG01300                      0               0              0
# ATCG01310                      0               0              0
# ENSRNA049494914                0               0              0
#
#                  col4-40_HPK-1S  col4-0.5_LPHK-3S
# Gene
# AT1G01010                     3                 1
# AT1G01020                    31                31
# AT1G03987                     1                 0
# AT1G01030                    21                12
# AT1G01040                    39                16
# ...                         ...               ...
# ATCG01280                     0                 0
# ATCG01290                     0                 0
# ATCG01300                     0                 0
# ATCG01310                     0                 0
# ENSRNA049494914               0                 0
#
# [34262 rows x 91 columns]

# %%
deg_df = pd.read_csv('data/SS/92_DEG_Clusters.csv', index_col=0)
deg_genes = deg_df.index

# %%
target_genes = pd.Series(list(set(deg_genes).intersection(set(ts_df.index))))

# %%
meta_df = pd.read_csv('data/TS/meta_data.tsv', sep='\t')
ts_exp_index = meta_df[meta_df['isTs']]
ss_exp_index = meta_df[meta_df['isTs'] == False].condName

# %%
ts_exp_index_target =  ts_exp_index[ts_exp_index['is1stLast'] != 'f'].condName
ts_exp_index_source =  ts_exp_index[ts_exp_index['is1stLast'] != 'f'].prevCol

# %%
len(ts_exp_index_source)
# Out:
# 20

# %%
regulator_gene_index = ts_df.index

# %%
from sklearn.ensemble import RandomForestRegressor

regr = RandomForestRegressor(random_state=0)


ts_train_y_list = ts_df[ts_exp_index_target]
ss_train_y_list = ts_df[ss_exp_index]

result_list = []
result_measure_list = []

target_gene = target_genes[1]

train_gene_index = regulator_gene_index[regulator_gene_index != target_gene]
ts_train_X = ts_df[ts_exp_index_source].T[train_gene_index]
ss_train_X = ts_df[ss_exp_index].T[train_gene_index]

ts_train_y = ts_train_y_list.loc[target_gene]
ss_train_y = ss_train_y_list.loc[target_gene]


importance_matrix = np.zeros((len(train_gene_index),100))
for i in tqdm(range(100)):
    regr = RandomForestRegressor(random_state=i, warm_start=True, n_estimators=300, n_jobs=20)
    regr = regr.fit(ts_train_X, ts_train_y)
    regr.n_estimators *= 2
    regr = regr.fit(ss_train_X, ss_train_y)
    importance_matrix[:,i] = regr.feature_importances_

importance_df = pd.DataFrame(index=train_gene_index, data=importance_matrix, columns=range(100))

mean_importance = importance_df.mean(axis=1)
top_influence_genes = train_gene_index[np.argsort(mean_importance)[-5:]]
data_mean = ts_df.T[top_influence_genes].mean()
data_std = ts_df.T[top_influence_genes].std()
regr = RandomForestRegressor(random_state=42, warm_start=True, n_estimators=100, n_jobs=20)
ts_train_X = ts_df[ts_exp_index_source].T[top_influence_genes]
ss_train_X = ts_df[ss_exp_index].T[top_influence_genes]
regr = regr.fit(ts_train_X, ts_train_y)
regr.n_estimators *= 2
regr = regr.fit(ss_train_X, ss_train_y)

base_prediction = regr.predict(np.array(data_mean).reshape(1,-1))[0]
y_std = ts_df.T.std()[target_gene]
perturbation_list = list(powerset(top_influence_genes))[1:]

perturbation_result_list = []
perturbation_list_names = ['; '.join(perturbation_genes) for perturbation_genes in perturbation_list]
for perturbation_genes in perturbation_list:
    perturbation_input = data_mean.copy()
    for gene in perturbation_genes:
        perturbation_input[gene] += data_std[gene] * perturbation_factor
    perturbation_prediction = regr.predict(np.array(perturbation_input).reshape(1,-1))[0]
    perturbation_measure = (perturbation_prediction - base_prediction)/y_std
    perturbation_result_list.append(perturbation_measure)
result_list.append(np.array(perturbation_list_names)[np.argsort(perturbation_result_list)[::-1][:5]])
result_measure_list.append(np.array(perturbation_result_list)[np.argsort(perturbation_result_list)[::-1][:5]])
# Out:
# 100%|██████████| 1000/1000 [21:08<00:00,  1.27s/it]

# %%
from sklearn.ensemble import RandomForestRegressor

regr = RandomForestRegressor(random_state=0)

ts_train_y_list = ts_df[ts_exp_index_target]
ss_train_y_list = ts_df[ss_exp_index]

result_list = []
result_measure_list = []

for target_gene in tqdm(target_genes):
    train_gene_index = regulator_gene_index[regulator_gene_index != target_gene]
    ts_train_X = ts_df[ts_exp_index_source].T[train_gene_index]
    ss_train_X = ts_df[ss_exp_index].T[train_gene_index]
    
    ts_train_y = ts_train_y_list.loc[target_gene]
    ss_train_y = ss_train_y_list.loc[target_gene]
    importance_matrix = np.zeros((len(train_gene_index),500))
    for i in range(500):
        regr = RandomForestRegressor(random_state=i, warm_start=True, n_estimators=300, n_jobs=20)
        regr = regr.fit(ts_train_X, ts_train_y)
        regr.n_estimators *= 2
        regr = regr.fit(ss_train_X, ss_train_y)
        importance_matrix[:,i] = regr.feature_importances_

    importance_df = pd.DataFrame(index=train_gene_index, data=importance_matrix, columns=range(500))

    mean_importance = importance_df.mean(axis=1)
    top_influence_genes = train_gene_index[np.argsort(mean_importance)[-5:]]
    data_mean = ts_df.T[top_influence_genes].mean()
    data_std = ts_df.T[top_influence_genes].std()
    regr = RandomForestRegressor(random_state=42, warm_start=True, n_estimators=100, n_jobs=20)
    ts_train_X = ts_df[ts_exp_index_source].T[top_influence_genes]
    ss_train_X = ts_df[ss_exp_index].T[top_influence_genes]
    regr = regr.fit(ts_train_X, ts_train_y)
    regr.n_estimators *= 2
    regr = regr.fit(ss_train_X, ss_train_y)

    base_prediction = regr.predict(np.array(data_mean).reshape(1,-1))[0]
    y_std = ts_df.T.std()[target_gene]
    perturbation_list = list(powerset(top_influence_genes))[1:]
'
 '
    perturbation_result_list = []
    perturbation_list_names = ['; '.join(perturbation_genes) for perturbation_genes in perturbation_list]
    for perturbation_genes in perturbation_list:
        perturbation_input = data_mean.copy()
        for gene in perturbation_genes:
            perturbation_input[gene] += data_std[gene] * perturbation_factor
        perturbation_prediction = regr.predict(np.array(perturbation_input).reshape(1,-1))[0]
        perturbation_measure = (perturbation_prediction - base_prediction)/y_std
        perturbation_result_list.append(perturbation_measure)
    result_list.append(np.array(perturbation_list_names)[np.argsort(perturbation_result_list)[::-1][:5]])
    result_measure_list.append(np.array(perturbation_result_list)[np.argsort(perturbation_result_list)[::-1][:5]])
# Out:
# 100%|██████████| 42/42 [12:11:00<00:00, 1044.29s/it]

# %%
result_measure_list = np.array(result_measure_list)
result_list = np.array(result_list)
out_df = pd.DataFrame()
out_df.index = target_genes
for i in range(5):
    comb_name = 'top_{}_combination'.format(i+1)
    score_name = 'top_{}_score'.format(i+1)
    out_df[comb_name] = result_list[:,i]
    out_df[score_name] = result_measure_list[:,i]

# %%
out_df.to_csv('output/aug22.csv')

# %%
from sklearn.ensemble import RandomForestRegressor

regr = RandomForestRegressor(random_state=0)

ts_train_y_list = ts_df[ts_exp_index_target]
ss_train_y_list = ts_df[ss_exp_index]

result_list = []
result_measure_list = []

for target_gene in tqdm(target_genes):
    train_gene_index = regulator_gene_index[regulator_gene_index != target_gene]
    ts_train_X = ts_df[ts_exp_index_source].T[train_gene_index]
    ss_train_X = ts_df[ss_exp_index].T[train_gene_index]
    
    ts_train_y = ts_train_y_list.loc[target_gene]
    ss_train_y = ss_train_y_list.loc[target_gene]
    regr = RandomForestRegressor(random_state=0, warm_start=True, n_estimators=1000, n_jobs=-1)
    regr = regr.fit(ts_train_X, ts_train_y)
    regr.n_estimators *= 2
    regr = regr.fit(ss_train_X, ss_train_y)

    top_influence_genes = train_gene_index[np.argsort(regr.feature_importances_)[-5:]]
    data_mean = ts_df.T[train_gene_index].mean()
    data_std = ts_df.T[train_gene_index].std()
    base_prediction = regr.predict(np.array(data_mean).reshape(1,-1))[0]
    y_std = ts_df.T.std()[target_gene]
    perturbation_list = list(powerset(top_influence_genes))[1:]
    perturbation_result_list = []
    perturbation_list_names = ['; '.join(perturbation_genes) for perturbation_genes in perturbation_list]
    for perturbation_genes in perturbation_list:
        perturbation_input = data_mean.copy()
        for gene in perturbation_genes:
            perturbation_input[gene] += data_std[gene] * perturbation_factor
        perturbation_prediction = regr.predict(np.array(perturbation_input).reshape(1,-1))[0]
        perturbation_measure = (perturbation_prediction - base_prediction)/y_std
        perturbation_result_list.append(perturbation_measure)
    result_list.append(np.array(perturbation_list_names)[np.argsort(perturbation_result_list)[::-1][:5]])
    result_measure_list.append(np.array(perturbation_result_list)[np.argsort(perturbation_result_list)[::-1][:5]])
# Out:
# 100%|██████████| 42/42 [07:07<00:00, 10.19s/it]

# %%
result_measure_list = np.array(result_measure_list)
result_list = np.array(result_list)
out_df = pd.DataFrame()
out_df.index = target_genes
for i in range(5):
    comb_name = 'top_{}_combination'.format(i+1)
    score_name = 'top_{}_score'.format(i+1)
    out_df[comb_name] = result_list[:,i]
    out_df[score_name] = result_measure_list[:,i]

# %%
out_df.to_csv('output/aug20.csv')

# %%
result_list = list(result_list)

# %%
len(result_list)
# Out:
# 42

# %%
np.array(perturbation_list_names)[np.argsort(perturbation_result_list)[::-1][:5]]
# Out:
# array(['AT2G46830; AT3G56980; AT2G02120; AT5G42900; AT1G49720',
#        'AT2G46830; AT2G02120; AT5G42900; AT1G49720',
#        'AT2G02120; AT5G42900; AT1G49720',
#        'AT3G56980; AT2G02120; AT5G42900; AT1G49720',
#        'AT2G46830; AT5G42900; AT1G49720'], dtype='<U53')

# %%
np.array(perturbation_result_list)[np.argsort(perturbation_result_list)[::-1][:5]]
# Out:
# array([0.95929503, 0.95929503, 0.95929503, 0.95929503, 0.88439046])

# %%
perturbation_result_list
# Out:
# [-1.9569584448767153e-15,
#  -9.784792224383576e-16,
#  0.06854242877885283,
#  0.09966652602273654,
#  2.0437406665328745e-05,
#  -9.784792224383576e-16,
#  0.06854242877885185,
#  0.09966652602273753,
#  2.0437406665328745e-05,
#  0.06854242877885088,
#  0.09966652602273753,
#  2.0437406667285703e-05,
#  0.16224539283533185,
#  0.06856286618551913,
#  0.0996747976147222,
#  0.06854242877885185,
#  0.09966652602273753,
#  2.0437406666307224e-05,
#  0.1622453928353338,
#  0.06856286618551816,
#  0.09967479761472317,
#  0.1622453928353338,
#  0.06856286618551816,
#  0.0996747976147222,
#  0.1622536644273224,
#  0.16224539283533282,
#  0.06856286618551816,
#  0.0996747976147222,
#  0.16225366442732045,
#  0.16225366442731945,
#  0.16225366442732142]

# %%
perturbation_list
# Out:
# [('AT2G46830',),
#  ('AT3G56980',),
#  ('AT2G02120',),
#  ('AT5G42900',),
#  ('AT1G49720',),
#  ('AT2G46830', 'AT3G56980'),
#  ('AT2G46830', 'AT2G02120'),
#  ('AT2G46830', 'AT5G42900'),
#  ('AT2G46830', 'AT1G49720'),
#  ('AT3G56980', 'AT2G02120'),
#  ('AT3G56980', 'AT5G42900'),
#  ('AT3G56980', 'AT1G49720'),
#  ('AT2G02120', 'AT5G42900'),
#  ('AT2G02120', 'AT1G49720'),
#  ('AT5G42900', 'AT1G49720'),
#  ('AT2G46830', 'AT3G56980', 'AT2G02120'),
#  ('AT2G46830', 'AT3G56980', 'AT5G42900'),
#  ('AT2G46830', 'AT3G56980', 'AT1G49720'),
#  ('AT2G46830', 'AT2G02120', 'AT5G42900'),
#  ('AT2G46830', 'AT2G02120', 'AT1G49720'),
#  ('AT2G46830', 'AT5G42900', 'AT1G49720'),
#  ('AT3G56980', 'AT2G02120', 'AT5G42900'),
#  ('AT3G56980', 'AT2G02120', 'AT1G49720'),
#  ('AT3G56980', 'AT5G42900', 'AT1G49720'),
#  ('AT2G02120', 'AT5G42900', 'AT1G49720'),
#  ('AT2G46830', 'AT3G56980', 'AT2G02120', 'AT5G42900'),
#  ('AT2G46830', 'AT3G56980', 'AT2G02120', 'AT1G49720'),
#  ('AT2G46830', 'AT3G56980', 'AT5G42900', 'AT1G49720'),
#  ('AT2G46830', 'AT2G02120', 'AT5G42900', 'AT1G49720'),
#  ('AT3G56980', 'AT2G02120', 'AT5G42900', 'AT1G49720'),
#  ('AT2G46830', 'AT3G56980', 'AT2G02120', 'AT5G42900', 'AT1G49720')]

# %%
perturbation_result_list
# Out:
# [0.0,
#  1.9569584448767153e-15,
#  0.08054430729805392,
#  0.4172836212229085,
#  0.9592950273570107,
#  0.9592950273570097,
#  0.9592950273570107,
#  0.9592950273570097,
#  0.9592950273570087,
#  0.9592950273570097,
#  0.9592950273570097,
#  0.9592950273570097,
#  0.9592950273570107,
#  0.9592950273570087,
#  0.9592950273570107,
#  0.9592950273570107,
#  0.9592950273570097,
#  0.9592950273570107,
#  0.9592950273570107,
#  0.9592950273570097,
#  0.9592950273570107,
#  0.9592950273570097,
#  0.9592950273570097,
#  0.9592950273570107,
#  0.9592950273570107,
#  0.9592950273570097,
#  0.9592950273570116,
#  0.9592950273570116,
#  0.9592950273570097,
#  0.9592950273570107,
#  0.9592950273570107]

# %%
base_prediction[0]
# Out:
# 4.1497932304199505

# %%
data_mean = ts_df.T.mean()
test = data_mean
test['AT2G23320'] += 1
test
# Out:
# AT2G23320    9.310273
# AT2G23290    6.933101
# AT2G47460    7.652201
# AT2G47520    6.876159
# AT4G25560    6.212827
#                ...
# AT2G26650    8.423390
# AT2G26690    5.907432
# AT2G26670    9.242888
# AT2G42250    6.493022
# AT2G42220    5.002517
# Length: 2286, dtype: float64

# %%
ts_df.T.mean()[target_gene]
# Out:
# 4.3544383771908395

# %%
regr.predict(np.array(ts_df.T.mean()).reshape(1, -1))
# Out:
# array([4.14979323])

# %%
np.max(regr.feature_importances_)
# Out:
# 0.26181176973389314
